# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
import numpy as np
from torchcfm.utils import sample_8gaussians, sample_moons
from physics_flow_matching.multi_fidelity.synthetic.dists.base import get_distribution
import torch
import matplotlib.pyplot as plt

# %%
samples = get_distribution("spiral").sample(10000).cpu().numpy()
samples_ = (samples - samples.mean(axis=0, keepdims=True))/ samples.std(axis=0, keepdims=True)
samples_neg = (-samples - (samples.mean(axis=0, keepdims=True)))/ samples.std(axis=0, keepdims=True)

# %%
plt.scatter(samples_[:, 0], samples_[:, 1] , alpha=0.5, c='r')
plt.scatter(-samples_[:, 0], -samples_[:, 1], alpha=0.5, c='b')
